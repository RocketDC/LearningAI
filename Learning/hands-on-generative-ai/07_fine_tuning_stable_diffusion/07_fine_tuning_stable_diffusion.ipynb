# %% [markdown]
# # Chapter 7: Fine-Tuning Stable Diffusion
#
# In this notebook, we look at the config files, weights format, and inference pipelines with Custom DreamBooth/LoRA weights.
#
# ## Official Resources
# - **Official Repo:** [genaibook/genaibook](https://github.com/genaibook/genaibook)
# - **Colab Launch:** [Open in Google Colab](https://colab.research.google.com/github/genaibook/genaibook/blob/main/chapter7.ipynb)

# %%
# Setup custom textual inversion or LoRA weights loading
# pipe.load_lora_weights("path_to_lora_weights.safetensors")
