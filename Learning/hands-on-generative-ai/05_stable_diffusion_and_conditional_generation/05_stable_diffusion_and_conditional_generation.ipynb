# %% [markdown]
# # Chapter 5: Stable Diffusion and Conditional Generation
#
# This notebook covers using the `diffusers` library to generate conditional images via Stable Diffusion pipelines.
#
# ## Official Resources
# - **Official Repo:** [genaibook/genaibook](https://github.com/genaibook/genaibook)
# - **Colab Launch:** [Open in Google Colab](https://colab.research.google.com/github/genaibook/genaibook/blob/main/chapter5.ipynb)

# %%
# Loading a stable diffusion pipeline
from diffusers import StableDiffusionPipeline
import torch

# Note: running on CPU can be very slow. Recommended on GPU.
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")

# model_id = "runwayml/stable-diffusion-v1-5"
# pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16 if device == "cuda" else torch.float32)
# pipe = pipe.to(device)
