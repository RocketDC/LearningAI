# %%
What's the role of attention machenisms in text Generation?
Ans -  Self Attention allows the model to identify how much each token contributes to the meaning of the sentence.

In which cases would a character-based tokenizer be preffered?
Ans - Like for suggesting a movie, classifying a movie based on positive and negative etc
