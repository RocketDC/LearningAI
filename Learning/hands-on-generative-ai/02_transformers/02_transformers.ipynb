# %% [markdown]
# # Chapter 2: Transformers
#
# In this notebook, you will explore the Transformer architecture, load pre-trained transformer models, and inspect tokenization and self-attention mappings.
#
# ## Official Resources
# - **Official Repo:** [genaibook/genaibook](https://github.com/genaibook/genaibook)
# - **Colab Launch:** [Open in Google Colab](https://colab.research.google.com/github/genaibook/genaibook/blob/main/chapter2.ipynb)

# %%
# Load a pipeline for text generation using a decoder-only model
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")
result = generator("Generative AI is transforming the way we", max_length=30, num_return_sequences=1)
print(result[0]['generated_text'])
