# %% [markdown]
# # Chapter 3: Compressing and Representing Information
#
# This notebook covers embeddings, latent spaces, and representing data mathematically for downstream generative tasks.
#
# ## Official Resources
# - **Official Repo:** [genaibook/genaibook](https://github.com/genaibook/genaibook)
# - **Colab Launch:** [Open in Google Colab](https://colab.research.google.com/github/genaibook/genaibook/blob/main/chapter3.ipynb)

# %%
# Using Hugging Face Transformers to generate embeddings
from transformers import AutoTokenizer, AutoModel
import torch

tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
model = AutoModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")

sentences = ["Generative AI is amazing!", "Machines can create art."]
inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")

with torch.no_grad():
    outputs = model(**inputs)

# Mean pooling to get a single vector per sentence
embeddings = outputs.last_hidden_state.mean(dim=1)
print(f"Embedding shape: {embeddings.shape}")
