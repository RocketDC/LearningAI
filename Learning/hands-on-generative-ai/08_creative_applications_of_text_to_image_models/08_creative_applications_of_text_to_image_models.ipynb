# %% [markdown]
# # Chapter 8: Creative Applications of Text-To-Image Models
#
# This notebook experiments with advanced image generation tasks including image-to-image, inpainting, and outpainting.
#
# ## Official Resources
# - **Official Repo:** [genaibook/genaibook](https://github.com/genaibook/genaibook)
# - **Colab Launch:** [Open in Google Colab](https://colab.research.google.com/github/genaibook/genaibook/blob/main/chapter8.ipynb)

# %%
# Import creative pipelines
from diffusers import StableDiffusionImg2ImgPipeline, StableDiffusionInpaintPipeline
