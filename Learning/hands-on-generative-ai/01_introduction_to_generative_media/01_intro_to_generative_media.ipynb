# %% [markdown]
# # Chapter 1: An Introduction to Generative Media
#
# Welcome to your hands-on notebook for Chapter 1. Here you will set up your environment, test the book's helper library `genaibook`, and run a basic pipeline to verify everything is working.
#
# ## Official Resources
# - **Official Repo:** [genaibook/genaibook](https://github.com/genaibook/genaibook)
# - **Colab Launch:** [Open in Google Colab](https://colab.research.google.com/github/genaibook/genaibook/blob/main/chapter1.ipynb)

# %%
# Install the genaibook helper library if not already installed
# !pip install genaibook transformers diffusers torch

# %%
# Verify installation and check versions
import torch
import transformers
import diffusers
import genaibook

print(f"PyTorch: {torch.__version__}")
print(f"Transformers: {transformers.__version__}")
print(f"Diffusers: {diffusers.__version__}")
print(f"GenAIBook: {genaibook.__version__}")
