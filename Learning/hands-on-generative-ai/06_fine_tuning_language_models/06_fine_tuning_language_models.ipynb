# %% [markdown]
# # Chapter 6: Fine-Tuning Language Models
#
# Learn how to load models in low-precision (4-bit/8-bit), prepare datasets, and set up LoRA adapters for fine-tuning.
#
# ## Official Resources
# - **Official Repo:** [genaibook/genaibook](https://github.com/genaibook/genaibook)
# - **Colab Launch:** [Open in Google Colab](https://colab.research.google.com/github/genaibook/genaibook/blob/main/chapter6.ipynb)

# %%
# Load PEFT configuration
from peft import LoraConfig, get_peft_model
from transformers import AutoModelForCausalLM

config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)
print("LoraConfig initialized successfully.")
